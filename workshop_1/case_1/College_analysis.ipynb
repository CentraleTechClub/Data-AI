# %%
import pandas as pd

# %%
dataframe = pd.read_csv("/content/salaries_by_college_major.csv")

# %%
dataframe.head()  #tail()  #sample(5)
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
dataframe.shape # taille du dataset
# Out:
# (51, 6)

# %%
dataframe.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Undergraduate Major                51 non-null     object
#  1   Starting Median Salary             50 non-null     float64
#  2   Mid-Career Median Salary           50 non-null     float64
#  3   Mid-Career 10th Percentile Salary  50 non-null     float64
#  4   Mid-Career 90th Percentile Salary  50 non-null     float64
#  5   Group                              50 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 2.5+ KB

# %%
dataframe.describe() # statistique descriptive
# Out:
#        Starting Median Salary  Mid-Career Median Salary  \
# count               50.000000                  50.00000
# mean             44310.000000               74786.00000
# std               9360.866217               16088.40386
# min              34000.000000               52000.00000
# 25%              37050.000000               60825.00000
# 50%              40850.000000               72000.00000
# 75%              49875.000000               88750.00000
# max              74300.000000              107000.00000
#
#        Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# count                          50.000000                          50.000000
# mean                        43408.000000                      142766.000000
# std                         12000.779567                       27851.249267
# min                         26700.000000                       96400.000000
# 25%                         34825.000000                      124250.000000
# ...

# %%
dataframe.isna().sum()
# Out:
# Undergraduate Major                  0
# Starting Median Salary               1
# Mid-Career Median Salary             1
# Mid-Career 10th Percentile Salary    1
# Mid-Career 90th Percentile Salary    1
# Group                                1
# dtype: int64

# %%
condition = dataframe['Starting Median Salary'].isna() == True
dataframe[condition]
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 50                                NaN                                NaN   NaN

# %%
df = dataframe.dropna()

# %%
df.isna().sum()
# Out:
# Undergraduate Major                  0
# Starting Median Salary               0
# Mid-Career Median Salary             0
# Mid-Career 10th Percentile Salary    0
# Mid-Career 90th Percentile Salary    0
# Group                                0
# dtype: int64

# %% [markdown]
# ### Highest salary

# %%
index_salary_highest = df["Starting Median Salary"].idxmax()
df.iloc[index_salary_highest]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %% [markdown]
# ### Lowest salary

# %%
index_salary_lowest = df["Starting Median Salary"].idxmin()
df.iloc[index_salary_lowest,1]
# Out:
# np.float64(34000.0)

# %%
# l'ecart minimum entre les top 10 mieux payés  et le top des moins bien payés

# %%
ecart = df['Mid-Career 90th Percentile Salary'] - df['Mid-Career 10th Percentile Salary']

# %%
ecart
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
df['Ecart'] = ecart
# Out:
# /tmp/ipython-input-1655293500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ecart'] = ecart

# %%
# ecart =  df['Mid-Career 90th Percentile Salary'] - df['Mid-Career 10th Percentile Salary']
#df.insert(1, 'Ecart', ecart)

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df.iloc[[df['Ecart'].idxmin()]]
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 40             Nursing                 54200.0                   67000.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 40                            47600.0                            98300.0
#
#        Group    Ecart
# 40  Business  50700.0

# %%
df.sort_values('Ecart', ascending=True)
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 40                               Nursing                 54200.0
# 43                   Physician Assistant                 74300.0
# 41                             Nutrition                 39900.0
# 49                               Spanish                 34000.0
# 27            Health Care Administration                 38800.0
# 47                              Religion                 34100.0
# 23                              Forestry                 39100.0
# 32                       Interior Design                 36100.0
# 18                             Education                 34900.0
# 15                      Criminal Justice                 35000.0
# 26                        Graphic Design                 35700.0
# 31           Information Technology (IT)                 49100.0
# 10                     Civil Engineering                 53900.0
# ...

# %%
grouped = df.groupby('Group')

# %%
grouped.mean(numeric_only=True).sort_values(by="Mid-Career 90th Percentile Salary",ascending= True)
# Out:
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# HASS                37186.363636              62968.181818
# Business            44633.333333              75083.333333
# STEM                53862.500000              90812.500000
#
#           Mid-Career 10th Percentile Salary  \
# Group
# HASS                           34145.454545
# Business                       43566.666667
# STEM                           56025.000000
#
#           Mid-Career 90th Percentile Salary          Ecart
# Group
# HASS                          129363.636364   95218.181818
# Business                      147525.000000  103958.333333
# STEM                          157625.000000  101600.000000

# %%
''' NB: Accedez à la documentation docstring d'une fonction avec cette syntaxe:
     dataframe.fonction?
'''
# Out:
# " NB: Accedez à la documentation docstring d'une fonction avec cette syntaxe:\n     dataframe.fonction?\n"
